# %%
import pandas as pd

crawl = pd.read_csv('all_crawling_data.csv')
pp = pd.read_csv('crawling_preprocess_data.csv')

# %%
print(crawl.shape)
print(pp.shape)
# Out:
# (12582, 35)
# (5035, 95)

# %%
crawl.head()
# Out:
#    home_FG  home_FGA  home_3P  home_3PA  home_FT  home_FTA  home_ORB  \
# 0     22.0      59.0      7.0      24.0     11.0      25.0      14.0
# 1     24.0      58.0     10.0      26.0     22.0      25.0       8.0
# 2     33.0      73.0      9.0      25.0      7.0      19.0      11.0
# 3     28.0      66.0      9.0      26.0     11.0      18.0      15.0
# 4     26.0      63.0     13.0      31.0      5.0      12.0       7.0
#
#    home_TRB  home_AST  home_STL  ...  away_TOV  away_PF  away_PTS  start_time  \
# 0      40.0      14.0       9.0  ...      21.0     26.0      57.0  2014-10-12
# 1      28.0      18.0       7.0  ...      14.0     20.0      67.0  2014-10-12
# 2      48.0      27.0       8.0  ...      12.0     18.0      56.0  2014-10-12
# 3      35.0      16.0       8.0  ...      13.0     19.0      66.0  2014-10-12
# 4      27.0      19.0       4.0  ...      11.0     18.0      78.0  2014-10-12
#
#                 away_team             home_team  away_team_score  \
# ...

# %%
pp.head()
# Out:
#   Tournament           Phase              Home Team               Away Team  \
# 0   Liga ACB  Regular Season   FC BARCELONA BÀSQUET          SASKI BASKONIA
# 1   Liga ACB  Regular Season  REAL BETIS BALONCESTO        CB 1939 CANARIAS
# 2   Liga ACB  Regular Season          OBRADOIRO CAB         BÀSQUET MANRESA
# 3   Liga ACB  Regular Season          BILBAO BASKET  BALONCESTO FUENLABRADA
# 4   Liga ACB  Regular Season         CB ESTUDIANTES         GIPUZKOA BASKET
#
#    Match Date  Team Points  Team Two Pointers Made  \
# 0  2014-10-04         87.0                    34.0
# 1  2014-10-04         87.0                    33.0
# 2  2014-10-04         88.0                    28.0
# 3  2014-10-05         73.0                    24.0
# 4  2014-10-05         91.0                    39.0
#
#    Team Two Pointers Attempted  Team Three Pointers Made  \
# 0                         54.0                      10.0
# 1                         66.0                       8.0
# ...
